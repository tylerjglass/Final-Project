# %%
import pandas as pd
import numpy as np

# %%
import ssl

ssl._create_default_https_context = ssl._create_unverified_context

# %%
pgh_SNAP_data = pd.read_csv("http://pghgis-pittsburghpa.opendata.arcgis.com/datasets/3ca13246362540fa8b4b567f84a1255b_0.csv")
                           
pgh_SNAP_data.head(10)
# Out:
#    OBJECTID  Neighborhood_2010_FID_BlockG  Neighborhood_2010_STATEFP10  \
# 0         1                             0                           42
# 1         2                             1                           42
# 2         3                             2                           42
# 3         4                             3                           42
# 4         5                             5                           42
# 5         6                             6                           42
# 6         7                             7                           42
# 7         8                             8                           42
# 8         9                            10                           42
# 9        10                            11                           42
#
#    Neighborhood_2010_COUNTYFP10  Neighborhood_2010_TRACTCE10  \
# 0                             3                        40500
# 1                             3                        40400
# ...
