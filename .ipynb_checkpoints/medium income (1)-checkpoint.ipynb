# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
import ssl

ssl._create_default_https_context = ssl._create_unverified_context

# %%
pgh_SNAP_data = pd.read_csv("https://data.wprdc.org/dataset/5b18c198-474c-4723-b735-cc5220ad43cc/resource/a071ae20-0510-4e3d-b388-c79ac5200c5a/download/social-security-income-in-the-past-12-months-for-households.csv")
                           
pgh_SNAP_data.sort_values(by='Estimate; Total: - With Social Security income')
# Out:
#                 Neighborhood  Id  Estimate; Total:  Margin of Error; Total:  \
# 71               South Shore  72               8.0                 9.000000
# 21                   Chateau  22               3.0                 3.000000
# 57               North Shore  58             154.0                45.122057
# 4          Arlington Heights   5             144.0                59.000000
# 87                  West End  88              99.0                47.000000
# 78                 St. Clair  79             101.0                42.000000
# 30                    Esplen  31             142.0                48.000000
# 80            Strip District  81             520.0                53.000000
# 1             Allegheny West   2             146.0                36.000000
# 31                 Fairywood  32             428.0                81.000000
# 37                      Hays  38             185.0                43.000000
# ...

# %%
pgh_SNAP_data.plot(kind='bar',x='Neighborhood',y='Estimate; Total: - With Social Security income')
plt.show()
