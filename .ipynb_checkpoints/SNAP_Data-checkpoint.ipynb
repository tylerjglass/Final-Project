# %%
import pandas as pd
import numpy as np

# %%
import ssl

ssl._create_default_https_context = ssl._create_unverified_context

# %%
pgh_SNAP_data = pd.read_csv("http://pghgis-pittsburghpa.opendata.arcgis.com/datasets/3ca13246362540fa8b4b567f84a1255b_0.csv",index_col=0)
                           
pgh_SNAP_data.head(10)
# Out:
#           Neighborhood_2010_FID_BlockG  Neighborhood_2010_STATEFP10  \
# OBJECTID
# 1                                    0                           42
# 2                                    1                           42
# 3                                    2                           42
# 4                                    3                           42
# 5                                    5                           42
# 6                                    6                           42
# 7                                    7                           42
# 8                                    8                           42
# 9                                   10                           42
# 10                                  11                           42
#
#           Neighborhood_2010_COUNTYFP10  Neighborhood_2010_TRACTCE10  \
# OBJECTID
# 1                                    3                        40500
# ...

# %%
#creating a new dataframe with just the data we're using
#for some reason it isn't getting neighborhoods with a medium home value greater than 100,000

new_data = pgh_SNAP_data[["Neighborhood_2010_HOOD","F__Pop__Change__00_10","SNAP_All_csv_2009_Median_Income", "SNAP_All_csv_Median_Home_Value_"]]
new_data = new_data.sort_values("SNAP_All_csv_Median_Home_Value_", ascending = False).head(10)
new_data
# Out:
#          Neighborhood_2010_HOOD F__Pop__Change__00_10  \
# OBJECTID
# 38                Highland Park                -5.25%
# 81                New Homestead                 5.66%
# 48                   Banksville                -8.72%
# 60             Allegheny Center                 5.30%
# 71           Point Breeze North               -10.85%
# 37               Swisshelm Park                -1.23%
# 15             South Side Flats                15.21%
# 9                   Summer Hill                 2.24%
# 78                      Oakwood                -0.10%
# 12                     Westwood                -0.87%
#
#           SNAP_All_csv_2009_Median_Income SNAP_All_csv_Median_Home_Value_
# OBJECTID
# 38                                  61455                         $99,900
# 81                                  83167                         $90,900
# 48                                  50625                         $87,200
# ...
